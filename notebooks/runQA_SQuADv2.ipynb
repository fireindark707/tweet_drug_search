# %% [markdown]
# # 環境準備

# %%
# !nvidia-smi #check GPU，Colab會自動分配GPU，顯存15G以上比較好，不然建議終止工作階段重連來隨機更換GPU（重啟不會更換GPU）
# Out:
# Sun Aug 15 12:03:39 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# 連結google drive，設定路徑

run_path = "/content/gdrive/MyDrive/tweet_drug_project/code/tweet_drug_search" 

from google.colab import drive
import os
drive.mount('/content/gdrive')
os.chdir(run_path) #更改路徑
os.getcwd()

import sys
sys.path.append(run_path) #添加當前路徑為sys path中，不然無法import
# Out:
# Mounted at /content/gdrive

# %%
# !pip install datasets transformers accelerate sentencepiece
# Out:
# Collecting datasets
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 7.2 MB/s
# Collecting transformers
#   Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 50.7 MB/s
# Collecting accelerate
#   Downloading accelerate-0.4.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.9 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 59.1 MB/s
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 65.6 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Collecting huggingface-hub<0.1.0
#   Downloading huggingface_hub-0.0.15-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.4 MB/s
# Requirement already satisfied: tqdm>=4.42 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.0)
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 66.4 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.5.30)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 59.4 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 57.9 MB/s
# Collecting huggingface-hub<0.1.0
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 56.8 MB/s
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from accelerate) (1.9.0+cu102)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.5.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Installing collected packages: xxhash, tokenizers, sacremoses, pyyaml, huggingface-hub, fsspec, transformers, sentencepiece, datasets, accelerate
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed accelerate-0.4.0 datasets-1.11.0 fsspec-2021.7.0 huggingface-hub-0.0.12 pyyaml-5.4.1 sacremoses-0.0.45 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.9.2 xxhash-2.0.2

# %%
import transformers

print(transformers.__version__) # version check, at least 4.8.1
# Out:
# 4.9.2

# %% [markdown]
# # 在QA資料集上微調 預訓練Language Model

# %% [markdown]
# 這個腳本會講解如何微調BERT等預訓練模型來進行QA任務，要注意的是，這個範例中的回答方式不是透過文本生成來回答問題，而是擷取給定Context中的文本片段來進行回答。目前，最常用的QA資料集為[SQuAD](https://rajpurkar.github.io/SQuAD-explorer/)，以下為SQuAD的範例：
#
# <img src="https://i.imgur.com/sOKTl1Z.jpg" width="500"/>

# %% [markdown]
# ## 超參數設定

# %%
squad_v2 = True # Switch between SQUAD v1 or 2
model_checkpoint = "bert-base-cased" # Download Model from HuggingFace Library, 可以跑BERT、ELECTRA、RoBERTa、DeBERTa，其他未測試
batch_size = 16

# %%
class arguments:
  def __init__(self,batch_size,model_checkpoint,squad_v2):
    self.dataset_name=None
    self.dataset_config_name=None
    self.train_file=None
    self.preprocessing_num_workers=4
    self.do_predict=False
    self.validation_file=None
    self.test_file=None
    self.max_seq_length=384
    self.pad_to_max_length=True
    self.model_name_or_path=model_checkpoint
    self.config_name=None
    self.tokenizer_name=None
    self.use_slow_tokenizer=False
    self.per_device_train_batch_size=batch_size
    self.per_device_eval_batch_size=batch_size
    self.learning_rate=3e-5
    self.weight_decay=0.01
    self.num_train_epochs=1 
    self.max_train_steps=None
    self.gradient_accumulation_steps=1 #顯存不夠大時設定，建議gradient_accumulation_steps*batch_size >= 16
    self.lr_scheduler_type="linear" 
    self.num_warmup_steps=0
    self.output_dir="./models/"
    self.seed=None
    self.doc_stride=128
    self.n_best_size=20 #輸出後處理，選擇多少「答案」作為候選
    self.null_score_diff_threshold=0.0
    self.version_2_with_negative=squad_v2
    self.max_answer_length=30
    self.max_train_samples=3000 #測試時請設定，不然會跑很久；正式訓練改為None
    self.max_eval_samples=None
    self.overwrite_cache=True
    self.max_predict_samples=None
    self.model_type=None

args = arguments(batch_size,model_checkpoint,squad_v2)

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這部分將使用[Datasets](https://github.com/huggingface/datasets) 提供的 `load_dataset` 來完成資料集準備。當然，直接從其他QA資料集的官方網站下載也可以。`load_metric` 是寫好的評估方法。如果要用自己的json、csv格式的dataset，load_dataset也可以完成。請看官方文檔[Datasets documentation](https://huggingface.co/docs/datasets/loading_datasets.html#from-local-files)。

# %%
from datasets import load_dataset, load_metric

datasets = load_dataset("squad_v2" if squad_v2 else "squad")
# Out:
# Downloading:   0%|          | 0.00/1.87k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# Downloading and preparing dataset squad_v2/squad_v2 (download: 44.34 MiB, generated: 122.41 MiB, post-processed: Unknown size, total: 166.75 MiB) to /root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d...
# Downloading:   0%|          | 0.00/9.55M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/801k [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset squad_v2 downloaded and prepared to /root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d. Subsequent calls will reuse this data.

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4) #只是為了漂亮印出Dict

print("datasets結構：\n")
pp.pprint(datasets)
print("\n\ntrain資料：\n")
pp.pprint(datasets['train'][0])
print("\n\nvalidation資料：\n")
pp.pprint(datasets['validation'][0])
# Out:
# datasets結構：
#
# {   'train': Dataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_rows: 130319
# }),
#     'validation': Dataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_rows: 11873
# })}
#
#
# train資料：
#
# {   'answers': {'answer_start': [269], 'text': ['in the late 1990s']},
#     'context': 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) '
#                '(born September 4, 1981) is an American singer, songwriter, '
#                'record producer and actress. Born and raised in Houston, '
#                'Texas, she performed in various singing and dancing '
#                'competitions as a child, and rose to fame in the late 1990s as '
#                "lead singer of R&B girl-group Destiny's Child. Managed by her "
#                "father, Mathew Knowles, the group became one of the world's "
#                'best-selling girl groups of all time. Their hiatus saw the '
#                "release of Beyoncé's debut album, Dangerously in Love (2003), "
#                'which established her as a solo artist worldwide, earned five '
#                'Grammy Awards and featured the Billboard Hot 100 number-one '
#                'singles "Crazy in Love" and "Baby Boy".',
#     'id': '56be85543aeaaa14008c9063',
#     'question': 'When did Beyonce start becoming popular?',
#     'title': 'Beyoncé'}
#
#
# validation資料：
#
# {   'answers': {   'answer_start': [159, 159, 159, 159],
#                    'text': ['France', 'France', 'France', 'France']},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '56ddde6b9a695914005b9628',
#     'question': 'In what country is Normandy located?',
#     'title': 'Normans'}

# %% [markdown]
# ## 訓練資料預處理

# %% [markdown]
# 通常Transformers提供的 Tokenizer 可以自動將文本Tokenize並轉換為model可以讀取的形式。BERT的輸入格式參考下方圖片：
#
# <img src="https://i.imgur.com/xQIkHWu.png" width="800" />

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(args.model_name_or_path)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
#預處理，主要處理的問題是部分passage可能超過設定的max_seq_length，因此需要切段落來製作train,eval並調整答案的index

from src.utils.dataset_preprocess import QAdataset

SQuAD_dataset = QAdataset(datasets,tokenizer,args)

train_dataset = SQuAD_dataset.generate_train_dataset()
eval_dataset = SQuAD_dataset.generate_eval_dataset()

print("train_dataset：\n")
pp.pprint(train_dataset)

print("\n\neval_dataset：\n")
pp.pprint(eval_dataset)
# Out:
# train_dataset：
#
# Dataset({
#     features: ['attention_mask', 'end_positions', 'input_ids', 'start_positions', 'token_type_ids'],
#     num_rows: 3000
# })
#
#
# eval_dataset：
#
# Dataset({
#     features: ['attention_mask', 'example_id', 'input_ids', 'offset_mapping', 'token_type_ids'],
#     num_rows: 12199
# })

# %% [markdown]
# ## 模型建構-Output Layer

# %%
from torch import nn
from torch.nn import CrossEntropyLoss

class QuestionAnsweringModelOutput: # Output layer輸出的資料格式
    def __init__(self,loss,start_logits,end_logits):
      self.loss = loss
      self.start_logits = start_logits
      self.end_logits = end_logits

class OutputQA(nn.Module): # Output layer，套用於預訓練模型上層

    def __init__(self,hidden_dim):
        super(OutputQA, self).__init__()
        self.num_labels = 2
        self.qa_outputs = nn.Linear(hidden_dim, 2) # Linear Layer, 輸出start, end logits 可視為預測得分

    def forward(
        self,
        outputs,
        start_positions=None,
        end_positions=None
    ):
        sequence_output = outputs[0] # last_hidden_state: batch size * seq_len * 768

        logits = self.qa_outputs(sequence_output) # batch size * seq_len * 2
        start_logits, end_logits = logits.split(1, dim=-1) # split to start and end logits, each shape: batch size * seq_len
        start_logits = start_logits.squeeze(-1).contiguous() # 1D: len = batch size * seq_len
        end_logits = end_logits.squeeze(-1).contiguous()

        total_loss = None
        if start_positions is not None and end_positions is not None:
            # If we are on multi-GPU, split add a dimension
            if len(start_positions.size()) > 1:
                start_positions = start_positions.squeeze(-1)
            if len(end_positions.size()) > 1:
                end_positions = end_positions.squeeze(-1)

            # 若start/end positions超出模型inputs範圍，直接忽略
            ignored_index = start_logits.size(1) # shape: batch size
            start_positions = start_positions.clamp(0, ignored_index) # clamp = into the range [ min, max ]
            end_positions = end_positions.clamp(0, ignored_index)

            # loss 計算
            loss_fct = CrossEntropyLoss(ignore_index=ignored_index) 
            start_loss = loss_fct(start_logits, start_positions)
            end_loss = loss_fct(end_logits, end_positions)
            total_loss = (start_loss + end_loss) / 2

        return QuestionAnsweringModelOutput(
            loss=total_loss,
            start_logits=start_logits,
            end_logits=end_logits
        )

# %% [markdown]
# ## Fine-tune模型

# %% [markdown]
# 現在資料就緒，可以使用Transformers預設好的`AutoModelForQuestionAnswering`進行預訓練，也可以自己定義。

# %%
from transformers import default_data_collator
from transformers import AdamW
from transformers import get_scheduler
from accelerate import Accelerator
from torch.utils.data.dataloader import DataLoader
import logging
import math
import os
import numpy as np
import torch
from tqdm.auto import tqdm

logger = logging.getLogger(__name__)

# %%
#載入模型
from transformers import RobertaModel,BertModel,ElectraModel,DebertaModel, AutoModel
import re

if re.search(r"roberta",args.model_name_or_path.lower()):
  model = RobertaModel.from_pretrained(args.model_name_or_path) 
elif re.search(r"electra",args.model_name_or_path.lower()):
  model = ElectraModel.from_pretrained(args.model_name_or_path) 
elif re.search(r"deberta",args.model_name_or_path.lower()):
  model = DebertaModel.from_pretrained(args.model_name_or_path) 
else:
  print("warning: Using AutoModel but not sure about the type of model_name_or_path.")
  model = AutoModel.from_pretrained(args.model_name_or_path) 

output_layer = OutputQA(model.config.hidden_size)
# Out:
# warning: Using AutoModel but not sure about the type of model_name_or_path.
# Downloading:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Dataloader

data_collator = default_data_collator 

train_dataloader = DataLoader(
        train_dataset, shuffle=True, collate_fn=data_collator, batch_size=args.per_device_train_batch_size
    )

eval_dataset_for_model = eval_dataset.remove_columns(["example_id", "offset_mapping"])
eval_dataloader = DataLoader(
        eval_dataset_for_model, collate_fn=data_collator, batch_size=args.per_device_eval_batch_size
    )

# %%
# Optimizer
# 權重分兩組，一個有weight decay，另一組不設。Weight dacay是在loss計算中加入懲罰，用來避免overfit。同時，Output Layer的LR通常要設置大於Bert的LR
no_decay = ["bias", "LayerNorm.weight"]
optimizer_grouped_parameters = [
    {
        "params": [p for n, p in output_layer.named_parameters() if not any(nd in n for nd in no_decay)],
        "weight_decay": args.weight_decay,
        "lr": args.learning_rate*10, # linear的lr設大一些
    },
    {
        "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
        "weight_decay": args.weight_decay,
    },
    {
        "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
        "weight_decay": 0.0,
    },
]
optimizer = AdamW(optimizer_grouped_parameters, lr=args.learning_rate)

# %%
# 用`accelerate`自動切換設備/多線程，跟寫.cuda()或.to(device)效果相同，可參考https://pypi.org/project/accelerate/

accelerator = Accelerator()
print(accelerator.state)

output_layer, model, optimizer, train_dataloader, eval_dataloader = accelerator.prepare(
    output_layer, model, optimizer, train_dataloader, eval_dataloader
) #back propagation時要用accelerator.backward(loss)取代loss.backward()
# Out:
# Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
# Use FP16 precision: False

# %%
# 根據步數設定學習率調整策略，可以調整args.lr_scheduler_type為其他策略，例如cosine
num_update_steps_per_epoch = math.ceil(len(train_dataloader) / args.gradient_accumulation_steps) #計算總訓練步數

if args.max_train_steps is None:
    args.max_train_steps = args.num_train_epochs * num_update_steps_per_epoch
else:
    args.num_train_epochs = math.ceil(args.max_train_steps / num_update_steps_per_epoch)

lr_scheduler = get_scheduler(
    name=args.lr_scheduler_type, #學習率調整策略
    optimizer=optimizer, 
    num_warmup_steps=args.num_warmup_steps, #warm up步數通常取總布數的1/10，這邊默認是0
    num_training_steps=args.max_train_steps,
)

# %%
# 訓練
total_batch_size = args.per_device_train_batch_size * accelerator.num_processes * args.gradient_accumulation_steps

print("***** Running training *****")
print(f"  Num examples = {len(train_dataset)}")
print(f"  Num Epochs = {args.num_train_epochs}")
print(f"  Instantaneous batch size per device = {args.per_device_train_batch_size}")
print(f"  Total train batch size (w. parallel, distributed & accumulation) = {total_batch_size}")
print(f"  Gradient Accumulation steps = {args.gradient_accumulation_steps}")
print(f"  Total optimization steps = {args.max_train_steps}")

# 進度條設定，disable部分是為了規定多個GPU時只顯示一個進度條，在Colab中有沒有都不影響
progress_bar = tqdm(range(args.max_train_steps), disable=not accelerator.is_local_main_process)

completed_steps = 0
for epoch in range(args.num_train_epochs):
    model.train()
    output_layer.train()
    for step, batch in enumerate(train_dataloader):
        input = {key: value for key, value in batch.items() if key not in ['start_positions','end_positions']}
        encoding = model(**input)
        outputs = output_layer(encoding,batch['start_positions'],batch['end_positions'])
        loss = outputs.loss
        loss = loss / args.gradient_accumulation_steps
        accelerator.backward(loss)
        if step % args.gradient_accumulation_steps == 0 or step == len(train_dataloader) - 1:
            optimizer.step()
            lr_scheduler.step()
            optimizer.zero_grad()
            progress_bar.update(1)
            completed_steps += 1

        if completed_steps >= args.max_train_steps:
            break
# Out:
# ***** Running training *****
#   Num examples = 3000
#   Num Epochs = 1
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 188
#   0%|          | 0/188 [00:00<?, ?it/s]

# %% [markdown]
# # 在eval集上評估
#
# ### 評估方法說明
#
# SQuAD使用exact match (EM)和F1 score。這些分數是根據單個「問題+答案」對計算的。當一個問題可能有多個正確答案時，計算所有可能的正確答案的最大分數。Model的EM和F1所有例子分數的平均分。
#
# #### Exact Match
#
# 對於每個問題+答案對，如果模型預測的詞句與（其中一個）真實答案的詞句完全匹配，EM=1，否則EM=0。嚴格的全有或全無指標；偏離一個詞句就會得到0分。
#
# #### F1
#
# 通過預測中的token與真實答案中的token進行計算的。預測和真實答案之間的共享token的數量來計算F1分數的基礎：Precision是共享token的數量與預測中的總token數的比率，Recall是共享token的數量與真實答案中的總token數的比率。

# %%
# 評估
from src.utils.utils_qa import * #post_processing_function, create_and_fill_np_array

squad_ver = "squad_v2" if args.version_2_with_negative else "squad"

print("***** Running Evaluation *****")
print(f"  Num examples = {len(eval_dataset)}")
print(f"  Batch size = {args.per_device_eval_batch_size}")
print(f"  squad_version = {squad_ver}")

metric = load_metric("squad_v2" if args.version_2_with_negative else "squad")

progress_bar = tqdm(range(len(eval_dataloader)), disable=not accelerator.is_local_main_process)

model.eval()
output_layer.eval()

all_start_logits = []
all_end_logits = []
for step, batch in enumerate(eval_dataloader):
    with torch.no_grad():
        encoding = model(**batch)
        outputs = output_layer(encoding)
        start_logits = outputs.start_logits
        end_logits = outputs.end_logits

        if not args.pad_to_max_length:  # 必須為預測做padding才能使用gather（accelerator的要求）
            start_logits = accelerator.pad_across_processes(start_logits, dim=1, pad_index=-100) # pad tensor across processes to max length
            end_logits = accelerator.pad_across_processes(end_logits, dim=1, pad_index=-100)

        all_start_logits.append(accelerator.gather(start_logits).cpu().numpy()) # 分佈式計算時用於集合預測結果
        all_end_logits.append(accelerator.gather(end_logits).cpu().numpy())
    progress_bar.update(1)

max_len = max([x.shape[1] for x in all_start_logits])  # 獲得最大長度

# concatenate array
start_logits_concat = create_and_fill_np_array(all_start_logits, eval_dataset, max_len)
end_logits_concat = create_and_fill_np_array(all_end_logits, eval_dataset, max_len)

# 使用完畢，刪除
del all_start_logits
del all_end_logits

outputs_numpy = (start_logits_concat, end_logits_concat) #預測結果
prediction = post_processing_function(datasets['validation'], eval_dataset, outputs_numpy,args) #後處理原理可以參考：https://qa.fastforwardlabs.com/no%20answer/null%20threshold/bert/distilbert/exact%20match/f1/robust%20predictions/2020/06/09/Evaluating_BERT_on_SQuAD.html#Metrics-for-QA
eval_metric = metric.compute(predictions=prediction.predictions, references=prediction.label_ids)
print(f"Evaluation metrics: {eval_metric}")
# Out:
# ***** Running Evaluation *****
#   Num examples = 12199
#   Batch size = 16
#   squad_version = squad_v2
# Downloading:   0%|          | 0.00/2.26k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.18k [00:00<?, ?B/s]
#   0%|          | 0/763 [00:00<?, ?it/s]
#   0%|          | 0/11873 [00:00<?, ?it/s]
# Evaluation metrics: {'exact': 24.307251747662765, 'f1': 30.215605692362747, 'total': 11873, 'HasAns_exact': 46.69365721997301, 'HasAns_f1': 58.52730876947081, 'HasAns_total': 5928, 'NoAns_exact': 1.984861227922624, 'NoAns_f1': 1.984861227922624, 'NoAns_total': 5945, 'best_exact': 50.10528088941295, 'best_exact_thresh': 0.0, 'best_f1': 50.10528088941295, 'best_f1_thresh': 0.0}

# %%
prediction.label_ids
# Out:
# [{'answers': {'answer_start': [159, 159, 159, 159],
#    'text': ['France', 'France', 'France', 'France']},
#   'id': '56ddde6b9a695914005b9628'},
#  {'answers': {'answer_start': [94, 87, 94, 94],
#    'text': ['10th and 11th centuries',
#     'in the 10th and 11th centuries',
#     '10th and 11th centuries',
#     '10th and 11th centuries']},
#   'id': '56ddde6b9a695914005b9629'},
#  {'answers': {'answer_start': [256, 256, 256, 256],
#    'text': ['Denmark, Iceland and Norway',
#     'Denmark, Iceland and Norway',
#     'Denmark, Iceland and Norway',
#     'Denmark, Iceland and Norway']},
#   'id': '56ddde6b9a695914005b962a'},
#  {'answers': {'answer_start': [308, 308, 308, 308],
#    'text': ['Rollo', 'Rollo', 'Rollo', 'Rollo']},
#   'id': '56ddde6b9a695914005b962b'},
#  {'answers': {'answer_start': [671, 649, 671, 671],
#    'text': ['10th century',
#     'the first half of the 10th century',
#     '10th',
#     '10th']},
#   'id': '56ddde6b9a695914005b962c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad39d53604f3c001a3fe8d1'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad39d53604f3c001a3fe8d2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad39d53604f3c001a3fe8d3'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad39d53604f3c001a3fe8d4'},
#  {'answers': {'answer_start': [1022, 1022, 1022],
#    'text': ['William the Conqueror',
#     'William the Conqueror',
#     'William the Conqueror']},
#   'id': '56dddf4066d3e219004dad5f'},
#  {'answers': {'answer_start': [573, 573, 573],
#    'text': ['Richard I', 'Richard I', 'Richard I']},
#   'id': '56dddf4066d3e219004dad60'},
#  {'answers': {'answer_start': [230, 230, 230],
#    'text': ['Catholic', 'Catholic orthodoxy', 'Catholic']},
#   'id': '56dddf4066d3e219004dad61'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3a266604f3c001a3fea27'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3a266604f3c001a3fea28'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3a266604f3c001a3fea29'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3a266604f3c001a3fea2a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3a266604f3c001a3fea2b'},
#  {'answers': {'answer_start': [341, 331, 331],
#    'text': ['Viking', 'Norseman, Viking', 'Norseman, Viking']},
#   'id': '56dde0379a695914005b9636'},
#  {'answers': {'answer_start': [309, 309, 309],
#    'text': ['9th century', '9th century', '9th century']},
#   'id': '56dde0379a695914005b9637'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ab70604f3c001a3feb89'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ab70604f3c001a3feb8a'},
#  {'answers': {'answer_start': [244, 244, 244], 'text': ['911', '911', '911']},
#   'id': '56dde0ba66d3e219004dad75'},
#  {'answers': {'answer_start': [324, 324, 324],
#    'text': ['King Charles III', 'King Charles III', 'King Charles III']},
#   'id': '56dde0ba66d3e219004dad76'},
#  {'answers': {'answer_start': [711, 524, 711],
#    'text': ['Seine', 'Epte', 'Seine']},
#   'id': '56dde0ba66d3e219004dad77'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ad61604f3c001a3fec0d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ad61604f3c001a3fec0e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ad61604f3c001a3fec0f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ad61604f3c001a3fec10'},
#  {'answers': {'answer_start': [7, 7, 7], 'text': ['Rollo', 'Rollo', 'Rollo']},
#   'id': '56dde1d966d3e219004dad8d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ae14604f3c001a3fec39'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ae14604f3c001a3fec3a'},
#  {'answers': {'answer_start': [121, 121, 121],
#    'text': ['Catholicism', 'Catholicism', 'Catholicism']},
#   'id': '56dde27d9a695914005b9651'},
#  {'answers': {'answer_start': [327, 323, 327],
#    'text': ['north', 'the north', 'north']},
#   'id': '56dde27d9a695914005b9652'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3af11604f3c001a3fec63'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3af11604f3c001a3fec64'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3af11604f3c001a3fec65'},
#  {'answers': {'answer_start': [428, 428, 428],
#    'text': ['fighting horsemen', 'fighting horsemen', 'fighting horsemen']},
#   'id': '56dde2fa66d3e219004dad9b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3c626604f3c001a3ff011'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3c626604f3c001a3ff012'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3c626604f3c001a3ff013'},
#  {'answers': {'answer_start': [161, 114, 157],
#    'text': ['Seljuk Turks',
#     'the Pechenegs, the Bulgars, and especially the Seljuk Turks',
#     'the Seljuk Turks']},
#   'id': '56de0f6a4396321400ee257f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3dbc6604f3c001a3ff3e9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3dbc6604f3c001a3ff3ea'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3dbc6604f3c001a3ff3eb'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3dbc6604f3c001a3ff3ec'},
#  {'answers': {'answer_start': [85, 78, 78],
#    'text': ['1050s', 'in the 1050s', 'in the 1050s']},
#   'id': '56de0ffd4396321400ee258d'},
#  {'answers': {'answer_start': [292, 285, 285],
#    'text': ['1060s', 'In the 1060s', 'In the 1060s']},
#   'id': '56de0ffd4396321400ee258e'},
#  {'answers': {'answer_start': [522, 522, 522],
#    'text': ['Alexius Komnenos', 'Alexius Komnenos', 'Alexius Komnenos']},
#   'id': '56de0ffd4396321400ee258f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3de8b604f3c001a3ff467'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3de8b604f3c001a3ff468'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3de8b604f3c001a3ff469'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3de8b604f3c001a3ff46a'},
#  {'answers': {'answer_start': [539, 539, 539],
#    'text': ['Afranji', 'Afranji', 'Afranji']},
#   'id': '56de10b44396321400ee2593'},
#  {'answers': {'answer_start': [256, 256, 256],
#    'text': ['Oursel', 'Oursel', 'Oursel']},
#   'id': '56de10b44396321400ee2594'},
#  {'answers': {'answer_start': [20, 20, 20],
#    'text': ['Turkish forces', 'Turkish forces', 'Turkish forces']},
#   'id': '56de10b44396321400ee2595'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3e96b604f3c001a3ff689'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3e96b604f3c001a3ff68a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3e96b604f3c001a3ff68b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3e96b604f3c001a3ff68c'},
#  {'answers': {'answer_start': [45, 217, 202],
#    'text': ['Norman mercenary',
#     'an Italo-Norman named Raoul',
#     'descended from an Italo-Norman named Raoul']},
#   'id': '56de11154396321400ee25aa'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ea79604f3c001a3ff6e9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ea79604f3c001a3ff6ea'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ea79604f3c001a3ff6eb'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['Robert Guiscard', 'Robert Guiscard', 'Robert Guiscard']},
#   'id': '56de148dcffd8e1900b4b5bc'},
#  {'answers': {'answer_start': [1315, 1306, 1306],
#    'text': ['1082', 'February 1082', 'February 1082']},
#   'id': '56de148dcffd8e1900b4b5bd'},
#  {'answers': {'answer_start': [492, 492, 492],
#    'text': ['30,000', '30,000', '30,000']},
#   'id': '56de148dcffd8e1900b4b5be'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ed26604f3c001a3ff799'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ed26604f3c001a3ff79a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ed26604f3c001a3ff79b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ed26604f3c001a3ff79c'},
#  {'answers': {'answer_start': [302, 718, 718],
#    'text': ['Deabolis', 'Deabolis', 'Deabolis']},
#   'id': '56de15104396321400ee25b7'},
#  {'answers': {'answer_start': [79, 79, 79],
#    'text': ['Bohemond', 'Bohemond', 'Bohemond']},
#   'id': '56de15104396321400ee25b8'},
#  {'answers': {'answer_start': [302, 292, 302],
#    'text': ['Deabolis', 'the river Deabolis', 'Deabolis']},
#   'id': '56de15104396321400ee25b9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ee2d604f3c001a3ff7e1'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ee2d604f3c001a3ff7e2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ee2d604f3c001a3ff7e3'},
#  {'answers': {'answer_start': [86, 83, 86],
#    'text': ['1185', 'in 1185', '1185']},
#   'id': '56de1563cffd8e1900b4b5c2'},
#  {'answers': {'answer_start': [125, 205, 205],
#    'text': ['Dyrrachium', 'Dyrrachium', 'Dyrrachium']},
#   'id': '56de1563cffd8e1900b4b5c3'},
#  {'answers': {'answer_start': [257, 257, 261],
#    'text': ['the Adriatic', 'the Adriatic', 'Adriatic']},
#   'id': '56de1563cffd8e1900b4b5c4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f028604f3c001a3ff823'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f028604f3c001a3ff824'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f028604f3c001a3ff825'},
#  {'answers': {'answer_start': [360, 365, 360],
#    'text': ['King Ethelred II', 'Ethelred II', 'King Ethelred II']},
#   'id': '56de15dbcffd8e1900b4b5c8'},
#  {'answers': {'answer_start': [327, 327, 327],
#    'text': ['Duke Richard II', 'Duke Richard II', 'Duke Richard II']},
#   'id': '56de15dbcffd8e1900b4b5c9'},
#  {'answers': {'answer_start': [423, 423, 423],
#    'text': ['Normandy', 'Normandy', 'Normandy']},
#   'id': '56de15dbcffd8e1900b4b5ca'},
#  {'answers': {'answer_start': [480, 480, 480],
#    'text': ['Sweyn Forkbeard', 'Sweyn Forkbeard', 'Sweyn Forkbeard']},
#   'id': '56de15dbcffd8e1900b4b5cb'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f187604f3c001a3ff86f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f187604f3c001a3ff870'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f187604f3c001a3ff871'},
#  {'answers': {'answer_start': [115, 115, 115],
#    'text': ['Harthacnut', 'Harthacnut', 'Harthacnut']},
#   'id': '56de1645cffd8e1900b4b5d0'},
#  {'answers': {'answer_start': [71, 68, 71],
#    'text': ['1041', 'in 1041', '1041']},
#   'id': '56de1645cffd8e1900b4b5d1'},
#  {'answers': {'answer_start': [382, 382, 382],
#    'text': ['Robert of Jumièges', 'Robert of Jumièges', 'Robert of Jumièges']},
#   'id': '56de1645cffd8e1900b4b5d2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f350604f3c001a3ff8ef'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f350604f3c001a3ff8f0'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f350604f3c001a3ff8f1'},
#  {'answers': {'answer_start': [85, 81, 78],
#    'text': ['Battle of Hastings',
#     'the Battle of Hastings',
#     'at the Battle of Hastings']},
#   'id': '56de16ca4396321400ee25c5'},
#  {'answers': {'answer_start': [14, 9, 9],
#    'text': ['William II', 'Duke William II', 'Duke William II']},
#   'id': '56de16ca4396321400ee25c6'},
#  {'answers': {'answer_start': [3, 0, 3], 'text': ['1066', 'In 1066', '1066']},
#   'id': '56de16ca4396321400ee25c7'},
#  {'answers': {'answer_start': [161, 157, 161],
#    'text': ['Anglo-Saxons', 'the Anglo-Saxons', 'Anglo-Saxons']},
#   'id': '56de16ca4396321400ee25c8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f4b1604f3c001a3ff951'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f4b1604f3c001a3ff952'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f4b1604f3c001a3ff953'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f4b1604f3c001a3ff954'},
#  {'answers': {'answer_start': [629, 629, 629],
#    'text': ['Modern English', 'Modern English', 'Modern English']},
#   'id': '56de1728cffd8e1900b4b5d7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f5b0604f3c001a3ff9ab'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f5b0604f3c001a3ff9ac'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f5b0604f3c001a3ff9ad'},
#  {'answers': {'answer_start': [101, 101, 101],
#    'text': ['1169', '1169', '1169']},
#   'id': '56de179dcffd8e1900b4b5da'},
#  {'answers': {'answer_start': [379, 379, 379],
#    'text': ['Ireland', 'Ireland', 'Ireland']},
#   'id': '56de179dcffd8e1900b4b5db'},
#  {'answers': {'answer_start': [37, 220, 220],
#    'text': ['Irish', 'Irish', 'Irish']},
#   'id': '56de179dcffd8e1900b4b5dc'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f6f5604f3c001a3ffa09'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f6f5604f3c001a3ffa0a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f6f5604f3c001a3ffa0b'},
#  {'answers': {'answer_start': [75, 157, 75],
#    'text': ['Edgar', 'Edgar', 'Edgar Atheling']},
#   'id': '56de17f9cffd8e1900b4b5e0'},
#  {'answers': {'answer_start': [120, 120, 120],
#    'text': ['King Malcolm III of Scotland',
#     'King Malcolm III',
#     'King Malcolm III']},
#   'id': '56de17f9cffd8e1900b4b5e1'},
#  {'answers': {'answer_start': [300, 300, 300],
#    'text': ['1072', '1072', '1072']},
#   'id': '56de17f9cffd8e1900b4b5e2'},
#  {'answers': {'answer_start': [440, 440, 440],
#    'text': ['Duncan', 'Duncan', 'Duncan']},
#   'id': '56de17f9cffd8e1900b4b5e3'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f7ac604f3c001a3ffa3b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f7ac604f3c001a3ffa3c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f7ac604f3c001a3ffa3d'},
#  {'answers': {'answer_start': [271, 271, 271],
#    'text': ['Sybilla of Normandy', 'Sybilla of Normandy', 'Sybilla']},
#   'id': '56de3cd0cffd8e1900b4b6be'},
#  {'answers': {'answer_start': [336, 336, 336],
#    'text': ['Norman', 'Norman', 'Norman']},
#   'id': '56de3cd0cffd8e1900b4b6bf'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f8d2604f3c001a3ffa8d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3f8d2604f3c001a3ffa8e'},
#  {'answers': {'answer_start': [158, 158, 158],
#    'text': ['Hereford', 'Hereford', 'Hereford']},
#   'id': '56de3d594396321400ee26ca'},
#  {'answers': {'answer_start': [227, 227, 227],
#    'text': ['the Welsh', 'the Welsh', 'the Welsh']},
#   'id': '56de3d594396321400ee26cb'},
#  {'answers': {'answer_start': [90, 90, 90],
#    'text': ['Edward the Confessor',
#     'Edward the Confessor',
#     'Edward the Confessor']},
#   'id': '56de3d594396321400ee26cc'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fb01604f3c001a3ffb35'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fb01604f3c001a3ffb36'},
#  {'answers': {'answer_start': [299, 299, 299],
#    'text': ['Wales', 'Wales', 'Wales']},
#   'id': '56de3dbacffd8e1900b4b6d2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fb6e604f3c001a3ffb5f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fb6e604f3c001a3ffb60'},
#  {'answers': {'answer_start': [221, 345, 221],
#    'text': ['1018', '1064', '1018']},
#   'id': '56de3e414396321400ee26d8'},
#  {'answers': {'answer_start': [380, 380, 380],
#    'text': ['William of Montreuil',
#     'William of Montreuil',
#     'William of Montreuil']},
#   'id': '56de3e414396321400ee26d9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fc41604f3c001a3ffb8f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fc41604f3c001a3ffb90'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fc41604f3c001a3ffb91'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fc41604f3c001a3ffb92'},
#  {'answers': {'answer_start': [267, 267, 267],
#    'text': ['1097', '1097', '1097']},
#   'id': '56de3ebc4396321400ee26e6'},
#  {'answers': {'answer_start': [100, 100, 100],
#    'text': ['Tancred', 'Tancred', 'Tancred']},
#   'id': '56de3ebc4396321400ee26e7'},
#  {'answers': {'answer_start': [390, 390, 390],
#    'text': ['Jerusalem', 'Jerusalem', 'Jerusalem']},
#   'id': '56de3ebc4396321400ee26e8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad4017a604f3c001a3ffd1f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad4017a604f3c001a3ffd20'},
#  {'answers': {'answer_start': [189, 189, 189],
#    'text': ['380 years', '380 years', '380 years']},
#   'id': '56de3efccffd8e1900b4b6fe'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad401f2604f3c001a3ffd41'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad401f2604f3c001a3ffd42'},
#  {'answers': {'answer_start': [99, 99, 99],
#    'text': ['a storm', 'a storm', 'a storm']},
#   'id': '56de3f784396321400ee26fa'},
#  {'answers': {'answer_start': [218, 218, 218],
#    'text': ['Berengaria', 'Berengaria', 'Berengaria']},
#   'id': '56de3f784396321400ee26fb'},
#  {'answers': {'answer_start': [9, 9, 9], 'text': ['1191', '1191', '1191']},
#   'id': '56de3f784396321400ee26fc'},
#  {'answers': {'answer_start': [421, 522, 421],
#    'text': ['Isaac Komnenos', 'Isaac', 'Isaac Komnenos']},
#   'id': '56de3f784396321400ee26fd'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40280604f3c001a3ffd57'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40280604f3c001a3ffd58'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40280604f3c001a3ffd59'},
#  {'answers': {'answer_start': [188, 188, 188],
#    'text': ['Conrad of Montferrat',
#     'Conrad of Montferrat',
#     'Conrad of Montferrat']},
#   'id': '56de40da4396321400ee2708'},
#  {'answers': {'answer_start': [565, 565, 565],
#    'text': ['silver', 'silver', 'silver']},
#   'id': '56de40da4396321400ee2709'},
#  {'answers': {'answer_start': [85, 508, 508],
#    'text': ['Guy de Lusignan', 'Guy de Lusignan', 'Guy de Lusignan']},
#   'id': '56de40da4396321400ee270a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad404a6604f3c001a3ffde1'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad404a6604f3c001a3ffde2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad404a6604f3c001a3ffde3'},
#  {'answers': {'answer_start': [219, 219, 219],
#    'text': ['Africa', 'Africa', 'Africa']},
#   'id': '56de49564396321400ee277a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40419604f3c001a3ffdb7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40419604f3c001a3ffdb8'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['Bethencourt', 'Bethencourt', 'Bethencourt']},
#   'id': '56de49a8cffd8e1900b4b7a7'},
#  {'answers': {'answer_start': [172, 172, 172],
#    'text': ['Enrique Pérez de Guzmán',
#     'Enrique Pérez de Guzmán',
#     'Enrique Pérez de Guzmán']},
#   'id': '56de49a8cffd8e1900b4b7a8'},
#  {'answers': {'answer_start': [116, 116, 116],
#    'text': ['Maciot de Bethencourt',
#     'Maciot de Bethencourt',
#     'Maciot de Bethencourt']},
#   'id': '56de49a8cffd8e1900b4b7a9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad403c1604f3c001a3ffd97'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad403c1604f3c001a3ffd98'},
#  {'answers': {'answer_start': [155, 151, 151],
#    'text': ['Channel Islands', 'the Channel Islands', 'the Channel Islands']},
#   'id': '56de4a474396321400ee2786'},
#  {'answers': {'answer_start': [212, 212, 212], 'text': ['two', 'two', 'two']},
#   'id': '56de4a474396321400ee2787'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40358604f3c001a3ffd7d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40358604f3c001a3ffd7e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad40358604f3c001a3ffd7f'},
#  {'answers': {'answer_start': [135, 135, 135],
#    'text': ['Romanesque', 'Romanesque', 'Romanesque']},
#   'id': '56de4a89cffd8e1900b4b7bd'},
#  {'answers': {'answer_start': [332, 332, 332],
#    'text': ['rounded', 'rounded', 'rounded']},
#   'id': '56de4a89cffd8e1900b4b7be'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad402ce604f3c001a3ffd67'},
#  {'answers': {'answer_start': [108, 108, 108],
#    'text': ['Early Gothic', 'Early Gothic', 'Early Gothic']},
#   'id': '56de4b074396321400ee2793'},
#  {'answers': {'answer_start': [79, 79, 79],
#    'text': ['Anglo-Saxon', 'Anglo-Saxon', 'Anglo-Saxon']},
#   'id': '56de4b074396321400ee2794'},
#  {'answers': {'answer_start': [328, 328, 317],
#    'text': ['Sicily', 'Sicily', 'Kingdom of Sicily']},
#   'id': '56de4b074396321400ee2795'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad400b0604f3c001a3ffcdf'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad400b0604f3c001a3ffce0'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad400b0604f3c001a3ffce1'},
#  {'answers': {'answer_start': [129, 135, 122],
#    'text': ['early 11th century',
#     '11th century',
#     'in the early 11th century']},
#   'id': '56de4b5c4396321400ee2799'},
#  {'answers': {'answer_start': [152, 422, 426],
#    'text': ['dukes', 'the dukes', 'dukes']},
#   'id': '56de4b5c4396321400ee279a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ffd7604f3c001a3ffca7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ffd7604f3c001a3ffca8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ffd7604f3c001a3ffca9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ffd7604f3c001a3ffcaa'},
#  {'answers': {'answer_start': [35, 31, 28],
#    'text': ['16th century', 'the 16th century', 'in the 16th century']},
#   'id': '56de4bb84396321400ee27a2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ff1b604f3c001a3ffc73'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3ff1b604f3c001a3ffc74'},
#  {'answers': {'answer_start': [104, 104, 104],
#    'text': ['embroidery', 'embroidery', 'embroidery']},
#   'id': '56de4c324396321400ee27ab'},
#  {'answers': {'answer_start': [49, 45, 45],
#    'text': ['Bayeux Tapestry', 'the Bayeux Tapestry', 'the Bayeux Tapestry']},
#   'id': '56de4c324396321400ee27ac'},
#  {'answers': {'answer_start': [139, 139, 139], 'text': ['Odo', 'Odo', 'Odo']},
#   'id': '56de4c324396321400ee27ad'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fe91604f3c001a3ffc47'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fe91604f3c001a3ffc48'},
#  {'answers': {'answer_start': [466, 466, 466],
#    'text': ['mosaics', 'mosaics', 'mosaics']},
#   'id': '56de51244396321400ee27ef'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fe0d604f3c001a3ffc1b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fe0d604f3c001a3ffc1c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fe0d604f3c001a3ffc1d'},
#  {'answers': {'answer_start': [97, 93, 97],
#    'text': ['11th', 'the 11th', '11th']},
#   'id': '56de51c64396321400ee27f7'},
#  {'answers': {'answer_start': [234, 234, 234],
#    'text': ['William of Volpiano and John of Ravenna',
#     'William of Volpiano and John of Ravenna',
#     'William of Volpiano and John of Ravenna']},
#   'id': '56de51c64396321400ee27f8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fd68604f3c001a3ffbe7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fd68604f3c001a3ffbe8'},
#  {'answers': {'answer_start': [179, 179, 179],
#    'text': ['southern Italy', 'southern Italy', 'southern Italy']},
#   'id': '56de52614396321400ee27fb'},
#  {'answers': {'answer_start': [259, 257, 278],
#    'text': ["Latin monastery at Sant'Eufemia.",
#     "a Latin monastery at Sant'Eufemia",
#     "Sant'Eufemia"]},
#   'id': '56de52614396321400ee27fc'},
#  {'answers': {'answer_start': [225, 225, 225],
#    'text': ['Robert Guiscard', 'Robert Guiscard', 'Robert Guiscard']},
#   'id': '56de52614396321400ee27fd'},
#  {'answers': {'answer_start': [32, 32, 330],
#    'text': ['singing', 'singing', 'singing']},
#   'id': '56de52614396321400ee27fe'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad3fccf604f3c001a3ffbb5'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['Computational complexity theory',
#     'Computational complexity theory',
#     'Computational complexity theory']},
#   'id': '56e16182e3433e1400422e28'},
#  {'answers': {'answer_start': [175, 169, 175],
#    'text': ['inherent difficulty',
#     'their inherent difficulty',
#     'inherent difficulty']},
#   'id': '56e16182e3433e1400422e29'},
#  {'answers': {'answer_start': [133, 238, 240],
#    'text': ['computational problems',
#     'A computational problem',
#     'computational problem']},
#   'id': '56e16182e3433e1400422e2a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5316b5b96ef001a10ab72'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5316b5b96ef001a10ab73'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5316b5b96ef001a10ab74'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5316b5b96ef001a10ab75'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5316b5b96ef001a10ab76'},
#  {'answers': {'answer_start': [46, 49, 46],
#    'text': ['if its solution requires significant resources',
#     'its solution requires significant resources',
#     'if its solution requires significant resources']},
#   'id': '56e16839cd28a01900c67887'},
#  {'answers': {'answer_start': [176, 176, 176],
#    'text': ['mathematical models of computation',
#     'mathematical models of computation',
#     'mathematical models of computation']},
#   'id': '56e16839cd28a01900c67888'},
#  {'answers': {'answer_start': [305, 305, 305],
#    'text': ['time and storage', 'time and storage', 'time and storage']},
#   'id': '56e16839cd28a01900c67889'},
#  {'answers': {'answer_start': [440, 440, 440],
#    'text': ['number of gates in a circuit',
#     'number of gates in a circuit',
#     'number of gates']},
#   'id': '56e16839cd28a01900c6788a'},
#  {'answers': {'answer_start': [615, 649, 615],
#    'text': ['determine the practical limits on what computers can and cannot do',
#     'what computers can and cannot do',
#     'determine the practical limits on what computers can and cannot do']},
#   'id': '56e16839cd28a01900c6788b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad532575b96ef001a10ab7c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad532575b96ef001a10ab7d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad532575b96ef001a10ab7e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad532575b96ef001a10ab7f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad532575b96ef001a10ab80'},
#  {'answers': {'answer_start': [59, 59, 59],
#    'text': ['analysis of algorithms and computability theory',
#     'analysis of algorithms and computability theory',
#     'analysis of algorithms and computability theory']},
#   'id': '56e17644e3433e1400422f40'},
#  {'answers': {'answer_start': [59, 134, 134],
#    'text': ['analysis of algorithms',
#     'analysis of algorithms',
#     'analysis of algorithms']},
#   'id': '56e17644e3433e1400422f41'},
#  {'answers': {'answer_start': [161, 161, 161],
#    'text': ['computational complexity theory',
#     'computational complexity theory',
#     'computational complexity theory']},
#   'id': '56e17644e3433e1400422f42'},
#  {'answers': {'answer_start': [86, 663, 663],
#    'text': ['computability theory',
#     'computability theory',
#     'computability theory']},
#   'id': '56e17644e3433e1400422f43'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5344b5b96ef001a10ab86'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5344b5b96ef001a10ab87'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5344b5b96ef001a10ab88'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5344b5b96ef001a10ab89'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5344b5b96ef001a10ab8a'},
#  {'answers': {'answer_start': [187, 185, 187],
#    'text': ['problem instance', 'a problem instance', 'problem instance']},
#   'id': '56e17a7ccd28a01900c679a1'},
#  {'answers': {'answer_start': [237, 293, 295],
#    'text': ['the problem', 'a problem', 'problem']},
#   'id': '56e17a7ccd28a01900c679a2'},
#  {'answers': {'answer_start': [402, 402, 317],
#    'text': ['concrete', 'concrete', 'abstract']},
#   'id': '56e17a7ccd28a01900c679a3'},
#  {'answers': {'answer_start': [67, 675, 679],
#    'text': ['instances', 'the instance', 'instance']},
#   'id': '56e17a7ccd28a01900c679a4'},
#  {'answers': {'answer_start': [93, 730, 734],
#    'text': ['solution', 'the solution', 'solution']},
#   'id': '56e17a7ccd28a01900c679a5'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5364c5b96ef001a10ab90'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5364c5b96ef001a10ab91'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5364c5b96ef001a10ab92'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5364c5b96ef001a10ab93'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5364c5b96ef001a10ab94'},
#  {'answers': {'answer_start': [190, 190, 190],
#    'text': ['2000', '2000', '2000']},
#   'id': '56e17e6ee3433e1400422f7f'},
#  {'answers': {'answer_start': [400, 387, 398],
#    'text': ['round trip through all sites in Milan',
#     'asking for a round trip through all sites in Milan whose total length is at most 10 km',
#     'a round trip through all sites in Milan whose total length is at most 10 km']},
#   'id': '56e17e6ee3433e1400422f80'},
#  {'answers': {'answer_start': [520, 520, 520],
#    'text': ['computational problems',
#     'computational problems',
#     'computational problems']},
#   'id': '56e17e6ee3433e1400422f81'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad537a15b96ef001a10ab9a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad537a15b96ef001a10ab9b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad537a15b96ef001a10ab9c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad537a15b96ef001a10ab9d'},
#  {'answers': {'answer_start': [43, 41, 43],
#    'text': ['problem instance', 'a problem instance', 'problem instance']},
#   'id': '56e181d9e3433e1400422fa0'},
#  {'answers': {'answer_start': [131, 131, 131],
#    'text': ['binary alphabet', 'binary', 'binary']},
#   'id': '56e181d9e3433e1400422fa1'},
#  {'answers': {'answer_start': [195, 195, 195],
#    'text': ['bitstrings', 'bitstrings', 'bitstrings']},
#   'id': '56e181d9e3433e1400422fa2'},
#  {'answers': {'answer_start': [349, 349, 349],
#    'text': ['binary notation', 'binary notation', 'binary notation']},
#   'id': '56e181d9e3433e1400422fa3'},
#  {'answers': {'answer_start': [411, 392],
#    'text': ['adjacency matrices', 'directly via their adjacency matrices']},
#   'id': '56e181d9e3433e1400422fa4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5391e5b96ef001a10aba2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5391e5b96ef001a10aba3'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5391e5b96ef001a10aba4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5391e5b96ef001a10aba5'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5391e5b96ef001a10aba6'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['Decision problems', 'Decision problems', 'Decision']},
#   'id': '56e190bce3433e1400422fc8'},
#  {'answers': {'answer_start': [179, 179, 179],
#    'text': ['yes or no', 'yes or no', 'yes or no']},
#   'id': '56e190bce3433e1400422fc9'},
#  {'answers': {'answer_start': [212, 212, 212],
#    'text': ['1 or 0', '1 or 0', '1 or 0']},
#   'id': '56e190bce3433e1400422fca'},
#  {'answers': {'answer_start': [179, 339, 339], 'text': ['yes', 'yes', 'yes']},
#   'id': '56e190bce3433e1400422fcb'},
#  {'answers': {'answer_start': [179, 605, 605], 'text': ['yes', 'yes', 'yes']},
#   'id': '56e190bce3433e1400422fcc'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53b9d5b96ef001a10abc8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53b9d5b96ef001a10abc9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53b9d5b96ef001a10abca'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53b9d5b96ef001a10abcb'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53b9d5b96ef001a10abcc'},
#  {'answers': {'answer_start': [67, 67, 67],
#    'text': ['arbitrary graph', 'arbitrary', 'arbitrary']},
#   'id': '56e19557e3433e1400422fee'},
#  {'answers': {'answer_start': [167, 163, 163],
#    'text': ['formal language',
#     'The formal language',
#     'The formal language associated with this decision problem']},
#   'id': '56e19557e3433e1400422ff0'},
#  {'answers': {'answer_start': [339, 339, 339],
#    'text': ['how graphs are encoded as binary strings',
#     'how graphs are encoded as binary strings',
#     'how graphs are encoded as binary strings']},
#   'id': '56e19557e3433e1400422ff1'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53d705b96ef001a10abd2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53d705b96ef001a10abd3'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53d705b96ef001a10abd4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53d705b96ef001a10abd5'},
#  {'answers': {'answer_start': [22, 22, 22],
#    'text': ['a computational problem',
#     'a computational problem',
#     'a computational problem']},
#   'id': '56e19724cd28a01900c679f6'},
#  {'answers': {'answer_start': [52, 54, 54],
#    'text': ['a single output', 'single', 'single']},
#   'id': '56e19724cd28a01900c679f7'},
#  {'answers': {'answer_start': [0, 2, 2],
#    'text': ['A function problem', 'function', 'function problem']},
#   'id': '56e19724cd28a01900c679f8'},
#  {'answers': {'answer_start': [277, 281, 281],
#    'text': ['the integer factorization problem',
#     'integer factorization',
#     'integer factorization problem']},
#   'id': '56e19724cd28a01900c679f9'},
#  {'answers': {'answer_start': [142, 142, 142],
#    'text': ['complex', 'complex', 'complex']},
#   'id': '56e19724cd28a01900c679fa'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53e615b96ef001a10abda'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53e615b96ef001a10abdb'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53e615b96ef001a10abdc'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53e615b96ef001a10abdd'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53e615b96ef001a10abde'},
#  {'answers': {'answer_start': [95, 190, 190],
#    'text': ['decision problems',
#     'as decision problems',
#     'as decision problems']},
#   'id': '56e1a0dccd28a01900c67a2e'},
#  {'answers': {'answer_start': [284, 374, 280],
#    'text': ['set of triples',
#     'triple',
#     'the set of triples (a, b, c) such that the relation a × b = c holds']},
#   'id': '56e1a0dccd28a01900c67a2f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53f815b96ef001a10abe4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53f815b96ef001a10abe5'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad53f815b96ef001a10abe6'},
#  {'answers': {'answer_start': [82, 91, 91],
#    'text': ['how much time the best algorithm requires to solve the problem',
#     'time',
#     'time']},
#   'id': '56e1a38de3433e140042305c'},
#  {'answers': {'answer_start': [199, 199, 405],
#    'text': ['the instance', 'the instance', 'the size of the instance']},
#   'id': '56e1a38de3433e140042305d'},
#  {'answers': {'answer_start': [388, 388, 391],
#    'text': ['as a function of the size of the instance',
#     'as a function of the size of the instance',
#     'a function of the size of the instance']},
#   'id': '56e1a38de3433e140042305e'},
#  {'answers': {'answer_start': [484, 484, 484],
#    'text': ['bits', 'bits', 'bits']},
#   'id': '56e1a38de3433e140042305f'},
#  {'answers': {'answer_start': [551, 570, 570],
#    'text': ['an increase in the input size', 'input size', 'input size']},
#   'id': '56e1a38de3433e1400423060'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad541ad5b96ef001a10abea'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad541ad5b96ef001a10abeb'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad541ad5b96ef001a10abec'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad541ad5b96ef001a10abed'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad541ad5b96ef001a10abee'},
#  {'answers': {'answer_start': [347, 347, 347],
#    'text': ["Cobham's thesis", "Cobham's", 'Cobham']},
#   'id': '56e1a564cd28a01900c67a48'},
#  {'answers': {'answer_start': [24, 24, 24],
#    'text': ['the time taken', 'the time taken', 'the time taken']},
#   'id': '56e1a564cd28a01900c67a49'},
#  {'answers': {'answer_start': [156, 156, 152],
#    'text': ['worst-case time complexity',
#     'worst-case time complexity',
#     'the worst-case time complexity']},
#   'id': '56e1a564cd28a01900c67a4a'},
#  {'answers': {'answer_start': [183, 183, 183],
#    'text': ['T(n)', 'T(n)', 'T(n)']},
#   'id': '56e1a564cd28a01900c67a4b'},
#  {'answers': {'answer_start': [320, 320, 320],
#    'text': ['polynomial time algorithm',
#     'polynomial time',
#     'polynomial time algorithm']},
#   'id': '56e1a564cd28a01900c67a4c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad542db5b96ef001a10abf4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad542db5b96ef001a10abf5'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad542db5b96ef001a10abf6'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad542db5b96ef001a10abf7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad542db5b96ef001a10abf8'},
#  {'answers': {'answer_start': [0, 0, 2],
#    'text': ['A Turing machine', 'A Turing machine', 'Turing machine']},
#   'id': '56e1aba0e3433e1400423094'},
#  {'answers': {'answer_start': [427, 427, 427],
#    'text': ['an algorithm', 'an algorithm', 'an algorithm']},
#   'id': '56e1aba0e3433e1400423095'},
#  {'answers': {'answer_start': [924, 924, 928],
#    'text': ['the Turing machine', 'the Turing machine', 'Turing machine']},
#   'id': '56e1aba0e3433e1400423097'},
#  {'answers': {'answer_start': [117, 117, 117],
#    'text': ['symbols', 'symbols', 'symbols']},
#   'id': '56e1aba0e3433e1400423098'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad543c05b96ef001a10abfe'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad543c05b96ef001a10abff'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad543c05b96ef001a10ac00'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad543c05b96ef001a10ac01'},
#  {'answers': {'answer_start': [0, 2, 2],
#    'text': ['A deterministic Turing machine',
#     'deterministic',
#     'deterministic Turing machine']},
#   'id': '56e1aff7cd28a01900c67a68'},
#  {'answers': {'answer_start': [91, 91, 76],
#    'text': ['rules',
#     'rules',
#     'a fixed set of rules to determine its future actions']},
#   'id': '56e1aff7cd28a01900c67a69'},
#  {'answers': {'answer_start': [130, 132, 132],
#    'text': ['A probabilistic Turing machine',
#     'probabilistic',
#     'probabilistic Turing machine']},
#   'id': '56e1aff7cd28a01900c67a6a'},
#  {'answers': {'answer_start': [398, 400, 400],
#    'text': ['A non-deterministic Turing machine',
#     'non-deterministic',
#     'non-deterministic Turing machine']},
#   'id': '56e1aff7cd28a01900c67a6b'},
#  {'answers': {'answer_start': [375, 375, 375],
#    'text': ['randomized algorithms',
#     'randomized algorithms',
#     'randomized algorithms']},
#   'id': '56e1aff7cd28a01900c67a6c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad546c75b96ef001a10ac0e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad546c75b96ef001a10ac0f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad546c75b96ef001a10ac10'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad546c75b96ef001a10ac11'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad546c75b96ef001a10ac12'},
#  {'answers': {'answer_start': [49, 49, 49],
#    'text': ['complexity classes', 'complexity classes', 'complexity classes']},
#   'id': '56e1b00ce3433e140042309e'},
#  {'answers': {'answer_start': [330, 330, 330],
#    'text': ['time or space', 'time or space', 'time or space']},
#   'id': '56e1b00ce3433e140042309f'},
#  {'answers': {'answer_start': [108, 108],
#    'text': ['probabilistic Turing machines, non-deterministic Turing machines',
#     'probabilistic Turing machines, non-deterministic Turing machines']},
#   'id': '56e1b00ce3433e14004230a1'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad545545b96ef001a10ac06'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad545545b96ef001a10ac07'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad545545b96ef001a10ac08'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad545545b96ef001a10ac09'},
#  {'answers': {'answer_start': [125, 125, 125],
#    'text': ['random access machines',
#     'random access machines',
#     'random access machines']},
#   'id': '56e1b169cd28a01900c67a72'},
#  {'answers': {'answer_start': [248, 248, 248],
#    'text': ['computational power',
#     'computational power',
#     'computational power']},
#   'id': '56e1b169cd28a01900c67a73'},
#  {'answers': {'answer_start': [273, 273, 273],
#    'text': ['time and memory',
#     'time and memory consumption',
#     'time and memory consumption']},
#   'id': '56e1b169cd28a01900c67a74'},
#  {'answers': {'answer_start': [382, 403, 382],
#    'text': ['the machines operate deterministically',
#     'deterministically',
#     'the machines operate deterministically']},
#   'id': '56e1b169cd28a01900c67a75'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad547945b96ef001a10ac18'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad547945b96ef001a10ac19'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad547945b96ef001a10ac1a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad547945b96ef001a10ac1b'},
#  {'answers': {'answer_start': [110, 110, 110],
#    'text': ['non-deterministic',
#     'non-deterministic',
#     'non-deterministic Turing machine']},
#   'id': '56e1b355e3433e14004230b0'},
#  {'answers': {'answer_start': [76, 71, 71],
#    'text': ['unusual resources',
#     'more unusual resources',
#     'more unusual resources']},
#   'id': '56e1b355e3433e14004230b1'},
#  {'answers': {'answer_start': [402, 402, 363],
#    'text': ['mathematical models', 'mathematical models', 'branching']},
#   'id': '56e1b355e3433e14004230b2'},
#  {'answers': {'answer_start': [468, 450, 450],
#    'text': ['time', 'non-deterministic time', 'non-deterministic time']},
#   'id': '56e1b355e3433e14004230b3'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5489b5b96ef001a10ac2a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5489b5b96ef001a10ac2b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5489b5b96ef001a10ac2c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5489b5b96ef001a10ac2d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad5489b5b96ef001a10ac2e'},
#  {'answers': {'answer_start': [261, 241, 245],
#    'text': ['state transitions',
#     'the total number of state transitions, or steps',
#     'total number of state transitions, or steps, the machine makes before it halts and outputs the answer']},
#   'id': '56e1b62ecd28a01900c67aa3'},
#  {'answers': {'answer_start': [695, 695, 695],
#    'text': ['difficulty', 'difficulty', 'difficulty']},
#   'id': '56e1b62ecd28a01900c67aa4'},
#  {'answers': {'answer_start': [873, 873, 873],
#    'text': ['DTIME(f(n))', 'DTIME(f(n)).', 'DTIME(f(n))']},
#   'id': '56e1b62ecd28a01900c67aa5'},
#  {'answers': {'answer_start': [85, 583, 583],
#    'text': ['time', 'time', 'time']},
#   'id': '56e1b62ecd28a01900c67aa6'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54a375b96ef001a10ac48'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54a375b96ef001a10ac49'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54a375b96ef001a10ac4a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54a375b96ef001a10ac4b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54a375b96ef001a10ac4c'},
#  {'answers': {'answer_start': [106, 106, 106],
#    'text': ['complexity resources', 'complexity resources', 'complexity']},
#   'id': '56e1b754cd28a01900c67abc'},
#  {'answers': {'answer_start': [170, 170, 170],
#    'text': ['computational resource', 'computational', 'computational']},
#   'id': '56e1b754cd28a01900c67abd'},
#  {'answers': {'answer_start': [248, 244, 244],
#    'text': ['Blum complexity axioms',
#     'the Blum complexity axioms',
#     'the Blum complexity axioms']},
#   'id': '56e1b754cd28a01900c67abe'},
#  {'answers': {'answer_start': [194, 278, 278],
#    'text': ['Complexity measures', 'complexity measures', 'complexity']},
#   'id': '56e1b754cd28a01900c67abf'},
#  {'answers': {'answer_start': [194, 278, 396],
#    'text': ['Complexity measures', 'complexity measures', 'complexity']},
#   'id': '56e1b754cd28a01900c67ac0'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54b035b96ef001a10ac52'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54b035b96ef001a10ac53'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54b035b96ef001a10ac54'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54b035b96ef001a10ac55'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54b035b96ef001a10ac56'},
#  {'answers': {'answer_start': [4, 4, 4],
#    'text': ['best, worst and average',
#     'best, worst and average case',
#     'best, worst and average case complexity']},
#   'id': '56e1b8f3e3433e14004230e6'},
#  {'answers': {'answer_start': [121, 121, 121],
#    'text': ['complexity measure', 'complexity', 'complexity']},
#   'id': '56e1b8f3e3433e14004230e7'},
#  {'answers': {'answer_start': [91, 91, 91],
#    'text': ['time', 'time complexity', 'time complexity']},
#   'id': '56e1b8f3e3433e14004230e8'},
#  {'answers': {'answer_start': [154, 154, 154],
#    'text': ['inputs', 'inputs', 'inputs']},
#   'id': '56e1b8f3e3433e14004230e9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54c2f5b96ef001a10ac5c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54c2f5b96ef001a10ac5d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54c2f5b96ef001a10ac5e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54c2f5b96ef001a10ac5f'},
#  {'answers': {'answer_start': [26, 58, 22],
#    'text': ['deterministic sorting algorithm quicksort',
#     'quicksort',
#     'the deterministic sorting algorithm quicksort']},
#   'id': '56e1ba41cd28a01900c67ae0'},
#  {'answers': {'answer_start': [155, 155, 155],
#    'text': ['worst-case', 'worst', 'worst-case']},
#   'id': '56e1ba41cd28a01900c67ae1'},
#  {'answers': {'answer_start': [251, 251, 251],
#    'text': ['O(n2)', 'O(n2)', 'O(n2)']},
#   'id': '56e1ba41cd28a01900c67ae2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54d625b96ef001a10ac64'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54d625b96ef001a10ac65'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54d625b96ef001a10ac66'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54d625b96ef001a10ac67'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54d625b96ef001a10ac68'},
#  {'answers': {'answer_start': [178, 178, 178],
#    'text': ['the most efficient algorithm',
#     'the most efficient algorithm',
#     'the most efficient algorithm solving a given problem']},
#   'id': '56e1bc3ae3433e1400423104'},
#  {'answers': {'answer_start': [399, 399, 399],
#    'text': ['analysis of algorithms',
#     'analysis of algorithms',
#     'analysis of algorithms']},
#   'id': '56e1bc3ae3433e1400423105'},
#  {'answers': {'answer_start': [123, 597, 597],
#    'text': ['lower bounds', 'lower', 'lower bounds']},
#   'id': '56e1bc3ae3433e1400423106'},
#  {'answers': {'answer_start': [434, 113, 434],
#    'text': ['upper bound', 'upper and lower bounds', 'upper bound']},
#   'id': '56e1bc3ae3433e1400423107'},
#  {'answers': {'answer_start': [676, 740, 740],
#    'text': ['all possible algorithms',
#     'all possible algorithms',
#     'all possible algorithms']},
#   'id': '56e1bc3ae3433e1400423108'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54e7c5b96ef001a10ac76'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54e7c5b96ef001a10ac77'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54e7c5b96ef001a10ac78'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54e7c5b96ef001a10ac79'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad54e7c5b96ef001a10ac7a'},
#  {'answers': {'answer_start': [52, 52, 52],
#    'text': ['big O notation', 'big O notation', 'big O notation']},
#   'id': '56e1bd4acd28a01900c67afc'},
#  {'answers': {'answer_start': [80, 80, 80],
#    'text': ['constant factors and smaller terms',
#     'constant factors and smaller terms',
# ...
#   'id': '57060cc352bb89140068980f'},
#  {'answers': {'answer_start': [374, 370, 374],
#    'text': ['San Fernando Valley',
#     'the San Fernando Valley',
#     'San Fernando Valley']},
#   'id': '57060cc352bb891400689810'},
#  {'answers': {'answer_start': [148, 148, 218],
#    'text': ['Los Angeles', 'Los Angeles', 'Los Angeles']},
#   'id': '57060cc352bb891400689811'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0470477cf76001a686f80'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0470477cf76001a686f81'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0470477cf76001a686f82'},
#  {'answers': {'answer_start': [48, 48, 48],
#    'text': ['business', 'business districts', 'business']},
#   'id': '57060df252bb891400689820'},
#  {'answers': {'answer_start': [19, 19, 182],
#    'text': ['Riverside', 'Riverside', 'Downtown Riverside']},
#   'id': '57060df252bb891400689821'},
#  {'answers': {'answer_start': [95, 182, 95],
#    'text': ['Hospitality Business/Financial Centre',
#     'Downtown Riverside',
#     'Hospitality Business/Financial Centre']},
#   'id': '57060df252bb891400689822'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0475c77cf76001a686f86'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0475c77cf76001a686f87'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['Orange', 'Orange County', 'Orange County']},
#   'id': '57060eaf75f01819005e7910'},
#  {'answers': {'answer_start': [268, 264, 268],
#    'text': ['University of California, Irvine',
#     'the University of California, Irvine',
#     'University of California']},
#   'id': '57060eaf75f01819005e7911'},
#  {'answers': {'answer_start': [302, 302, 302],
#    'text': ['West Irvine', 'West Irvine', 'West Irvine']},
#   'id': '57060eaf75f01819005e7912'},
#  {'answers': {'answer_start': [92, 88, 92],
#    'text': ['South Coast Metro',
#     'the South Coast Metro',
#     'South Coast Metro']},
#   'id': '57060eaf75f01819005e7913'},
#  {'answers': {'answer_start': [19, 19, 19],
#    'text': ['rapidly', 'rapidly', 'rapidly']},
#   'id': '57060eaf75f01819005e7914'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0483977cf76001a686f8a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0483977cf76001a686f8b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0483977cf76001a686f8c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0483977cf76001a686f8d'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['Downtown San Diego', 'Downtown San Diego', 'Downtown']},
#   'id': '57060f3e75f01819005e7922'},
#  {'answers': {'answer_start': [271, 271, 271],
#    'text': ['Northern San Diego', 'Northern San Diego', 'Northern San Diego']},
#   'id': '57060f3e75f01819005e7923'},
#  {'answers': {'answer_start': [306, 306, 306],
#    'text': ['North County', 'North County', 'North County regions']},
#   'id': '57060f3e75f01819005e7924'},
#  {'answers': {'answer_start': [55, 55, 9],
#    'text': ['San Diego', 'San Diego', 'San Diego']},
#   'id': '57060f3e75f01819005e7925'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04b2377cf76001a686f92'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04b2377cf76001a686f93'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04b2377cf76001a686f94'},
#  {'answers': {'answer_start': [31, 31, 31],
#    'text': ['Los Angeles International Airport',
#     'Los Angeles International Airport',
#     'Los Angeles International Airport']},
#   'id': '570610b275f01819005e792a'},
#  {'answers': {'answer_start': [117, 117, 117],
#    'text': ['passenger volume', 'passenger volume', 'passenger volume']},
#   'id': '570610b275f01819005e792b'},
#  {'answers': {'answer_start': [194, 194, 194],
#    'text': ['third', 'third', 'third']},
#   'id': '570610b275f01819005e792c'},
#  {'answers': {'answer_start': [314, 314, 314],
#    'text': ['San Diego International Airport',
#     'San Diego International Airport',
#     'San Diego International Airport']},
#   'id': '570610b275f01819005e792d'},
#  {'answers': {'answer_start': [394, 394, 394],
#    'text': ['Van Nuys Airport', 'Van Nuys Airport', 'Van Nuys Airport']},
#   'id': '570610b275f01819005e792e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04bfc77cf76001a686f98'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04bfc77cf76001a686f99'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04bfc77cf76001a686f9a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04bfc77cf76001a686f9b'},
#  {'answers': {'answer_start': [52, 52, 52],
#    'text': ['Metrolink', 'Metrolink', 'Metrolink']},
#   'id': '5706111a52bb89140068984c'},
#  {'answers': {'answer_start': [11, 11, 11],
#    'text': ['seven', 'seven', 'seven']},
#   'id': '5706111a52bb89140068984d'},
#  {'answers': {'answer_start': [0, 0, 0], 'text': ['Six', 'Six', 'Six']},
#   'id': '5706111a52bb89140068984e'},
#  {'answers': {'answer_start': [249, 249, 249],
#    'text': ['Orange', 'Orange', 'Orange']},
#   'id': '5706111a52bb89140068984f'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04d3077cf76001a686fa0'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04d3077cf76001a686fa1'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04d3077cf76001a686fa2'},
#  {'answers': {'answer_start': [40, 36, 40],
#    'text': ['Port of Los Angeles',
#     'the Port of Los Angeles',
#     'Port of Los Angeles']},
#   'id': '570611c475f01819005e793c'},
#  {'answers': {'answer_start': [196, 118, 118],
#    'text': ['Port of San Diego', 'Port of Long Beach', 'Port of Long Beach']},
#   'id': '570611c475f01819005e793d'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['Southern', 'Southern California', 'Southern']},
#   'id': '570611c475f01819005e793e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04de377cf76001a686fa6'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04de377cf76001a686fa7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04de377cf76001a686fa8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04de377cf76001a686fa9'},
#  {'answers': {'answer_start': [0, 0, 4],
#    'text': ['The Tech Coast', 'The Tech Coast', 'Tech Coast']},
#   'id': '5706139252bb891400689864'},
#  {'answers': {'answer_start': [183, 183, 183],
#    'text': ['research', 'research', 'research']},
#   'id': '5706139252bb891400689865'},
#  {'answers': {'answer_start': [579, 579, 579],
#    'text': ['private', 'private', 'private']},
#   'id': '5706139252bb891400689866'},
#  {'answers': {'answer_start': [270, 270, 270], 'text': ['5', '5', '5']},
#   'id': '5706139252bb891400689867'},
#  {'answers': {'answer_start': [370, 370, 370], 'text': ['12', '12', '12']},
#   'id': '5706139252bb891400689868'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04ecf77cf76001a686fae'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04ecf77cf76001a686faf'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04ecf77cf76001a686fb0'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04ecf77cf76001a686fb1'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04ecf77cf76001a686fb2'},
#  {'answers': {'answer_start': [72, 0, 72],
#    'text': ['NFL', 'Professional', 'NFL']},
#   'id': '5706143575f01819005e7950'},
#  {'answers': {'answer_start': [116, 116, 116], 'text': ['NBA', 'NBA', 'NBA']},
#   'id': '5706143575f01819005e7951'},
#  {'answers': {'answer_start': [164, 164, 164], 'text': ['MLB', 'MLB', 'MLB']},
#   'id': '5706143575f01819005e7952'},
#  {'answers': {'answer_start': [245, 245, 245],
#    'text': ['Los Angeles Kings', 'Los Angeles Kings', 'Los Angeles Kings']},
#   'id': '5706143575f01819005e7953'},
#  {'answers': {'answer_start': [289, 289, 289],
#    'text': ['LA Galaxy', 'LA Galaxy', 'LA Galaxy']},
#   'id': '5706143575f01819005e7954'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04f7977cf76001a686fb8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04f7977cf76001a686fb9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04f7977cf76001a686fba'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04f7977cf76001a686fbb'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad04f7977cf76001a686fbc'},
#  {'answers': {'answer_start': [95, 179, 179],
#    'text': ['Chivas USA', 'Chivas', 'Chivas']},
#   'id': '5706149552bb891400689880'},
#  {'answers': {'answer_start': [30, 30, 30], 'text': ['two', 'two', 'two']},
#   'id': '5706149552bb891400689881'},
#  {'answers': {'answer_start': [13, 215, 215],
#    'text': ['2014', '2014', '2014']},
#   'id': '5706149552bb891400689882'},
#  {'answers': {'answer_start': [132, 128, 132],
#    'text': ['StubHub Center', 'the StubHub Center', 'StubHub Center']},
#   'id': '5706149552bb891400689883'},
#  {'answers': {'answer_start': [278, 275, 278],
#    'text': ['2018', 'in 2018', '2018']},
#   'id': '5706149552bb891400689884'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad050c877cf76001a686fc2'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad050c877cf76001a686fc3'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad050c877cf76001a686fc4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad050c877cf76001a686fc5'},
#  {'answers': {'answer_start': [0, 0, 0],
#    'text': ['College', 'College', 'College']},
#   'id': '570614ff52bb89140068988a'},
#  {'answers': {'answer_start': [60, 60, 60], 'text': ['UCLA', 'UCLA', 'UCLA']},
#   'id': '570614ff52bb89140068988b'},
#  {'answers': {'answer_start': [84, 84, 84],
#    'text': ['Trojans', 'Trojans', 'Trojans']},
#   'id': '570614ff52bb89140068988c'},
#  {'answers': {'answer_start': [135, 131, 135],
#    'text': ['Pac-12', 'the Pac-12', 'Pac-12']},
#   'id': '570614ff52bb89140068988d'},
#  {'answers': {'answer_start': [117, 117, 117],
#    'text': ['Division I', 'Division I', 'Division I']},
#   'id': '570614ff52bb89140068988e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0511577cf76001a686fca'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0511577cf76001a686fcb'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad0511577cf76001a686fcc'},
#  {'answers': {'answer_start': [0, 0, 0], 'text': ['Rugby', 'Rugby', 'Rugby']},
#   'id': '5706155352bb891400689894'},
#  {'answers': {'answer_start': [74, 74, 74],
#    'text': ['high school', 'high school', 'high school']},
#   'id': '5706155352bb891400689895'},
#  {'answers': {'answer_start': [144, 144, 147],
#    'text': ['an official school sport',
#     'an official school',
#     'official school sport']},
#   'id': '5706155352bb891400689896'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5ad051be77cf76001a686fd0'},
#  {'answers': {'answer_start': [98, 98, 98],
#    'text': ['BSkyB', 'BSkyB', 'BSkyB']},
#   'id': '57092322efce8f15003a7db0'},
#  {'answers': {'answer_start': [98, 98, 98],
#    'text': ['BSkyB', 'BSkyB', 'BSkyB']},
#   'id': '57092322efce8f15003a7db1'},
#  {'answers': {'answer_start': [187, 187, 187],
#    'text': ['2014', '2014', '2014']},
#   'id': '57092322efce8f15003a7db2'},
#  {'answers': {'answer_start': [361, 306, 306],
#    'text': ['Sky plc',
#     'British Sky Broadcasting Group plc',
#     'British Sky Broadcasting Group plc']},
#   'id': '57092322efce8f15003a7db3'},
#  {'answers': {'answer_start': [471, 471, 471],
#    'text': ['Sky UK Limited', 'Sky UK Limited', 'Sky UK Limited']},
#   'id': '57092322efce8f15003a7db4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c08aebfd06b001a5ae989'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c08aebfd06b001a5ae98a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c08aebfd06b001a5ae98b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c08aebfd06b001a5ae98c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c08aebfd06b001a5ae98d'},
#  {'answers': {'answer_start': [231, 231, 231],
#    'text': ['2006', '2006', '2006']},
#   'id': '57094a79efce8f15003a7dc4'},
#  {'answers': {'answer_start': [286, 286, 286], 'text': ['two', 'two', 'two']},
#   'id': '57094a79efce8f15003a7dc5'},
#  {'answers': {'answer_start': [370, 370, 370], 'text': ['Sky', 'Sky', 'Sky']},
#   'id': '57094a79efce8f15003a7dc6'},
#  {'answers': {'answer_start': [407, 407, 441],
#    'text': ['£1.3bn', '£1.3bn', '£4.2bn']},
#   'id': '57094a79efce8f15003a7dc7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c0c2fbfd06b001a5ae99b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c0c2fbfd06b001a5ae99c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c0c2fbfd06b001a5ae99d'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c0c2fbfd06b001a5ae99e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c0c2fbfd06b001a5ae99f'},
#  {'answers': {'answer_start': [55, 55, 55],
#    'text': ['ONdigital', 'ONdigital', 'ONdigital']},
#   'id': '57094b4f9928a814004714f6'},
#  {'answers': {'answer_start': [184, 145, 145],
#    'text': ['Freeview', 'ITV Digital', 'ITV Digital']},
#   'id': '57094b4f9928a814004714f7'},
#  {'answers': {'answer_start': [307, 307, 307],
#    'text': ['three', 'three', 'three']},
#   'id': '57094b4f9928a814004714f8'},
#  {'answers': {'answer_start': [485, 485, 485],
#    'text': ['Sky Three', 'Sky Three', 'Sky Three']},
#   'id': '57094b4f9928a814004714f9'},
#  {'answers': {'answer_start': [553, 553, 553],
#    'text': ['Pick TV', 'Pick TV', 'Pick TV']},
#   'id': '57094b4f9928a814004714fa'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c14b4bfd06b001a5ae9d3'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c14b4bfd06b001a5ae9d4'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c14b4bfd06b001a5ae9d5'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c14b4bfd06b001a5ae9d6'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c14b4bfd06b001a5ae9d7'},
#  {'answers': {'answer_start': [65, 65, 65],
#    'text': ['Sky+ PVR', 'Sky+ PVR', 'Sky+ PVR']},
#   'id': '57094ca7efce8f15003a7dd6'},
#  {'answers': {'answer_start': [801, 801, 894],
#    'text': ['September 2007', 'September 2007', 'March 2008']},
#   'id': '57094ca7efce8f15003a7dd7'},
#  {'answers': {'answer_start': [403, 401, 760],
#    'text': ['monthly fee', 'a monthly fee', 'SkyHD box']},
#   'id': '57094ca7efce8f15003a7dd8'},
#  {'answers': {'answer_start': [444, 441, 652],
#    'text': ['January 2010', 'In January 2010', 'February 2011']},
#   'id': '57094ca7efce8f15003a7dd9'},
#  {'answers': {'answer_start': [570, 570, 570],
#    'text': ['Sky+HD Box', 'Sky+HD Box', 'Sky+HD Box']},
#   'id': '57094ca7efce8f15003a7dda'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c16e3bfd06b001a5ae9e7'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c16e3bfd06b001a5ae9e8'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c16e3bfd06b001a5ae9e9'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c16e3bfd06b001a5ae9ea'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c16e3bfd06b001a5ae9eb'},
#  {'answers': {'answer_start': [19, 19, 19],
#    'text': ['VideoGuard', 'VideoGuard pay-TV', 'VideoGuard']},
#   'id': '57094d489928a8140047150a'},
#  {'answers': {'answer_start': [64, 64, 64], 'text': ['NDS', 'NDS', 'NDS']},
#   'id': '57094d489928a8140047150b'},
#  {'answers': {'answer_start': [71, 71, 71],
#    'text': ['Cisco Systems', 'Cisco Systems', 'Cisco Systems company']},
#   'id': '57094d489928a8140047150c'},
#  {'answers': {'answer_start': [229, 229, 229],
#    'text': ['BSkyB', 'BSkyB', 'BSkyB']},
#   'id': '57094d489928a8140047150d'},
#  {'answers': {'answer_start': [539, 539, 516],
#    'text': ['Sky+', 'Sky+', 'PVR']},
#   'id': '57094d489928a8140047150e'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c3a5cbfd06b001a5aea79'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c3a5cbfd06b001a5aea7a'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c3a5cbfd06b001a5aea7b'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c3a5cbfd06b001a5aea7c'},
#  {'answers': {'answer_start': [], 'text': []},
#   'id': '5a2c3a5cbfd06b001a5aea7d'},
#  {'answers': {'answer_start': [3, 3, 3], 'text': ['2007', '2007', '2007']},
#   'id': '570953a7efce8f15003a7dfe'},
#  ...]

# %%
# 測試看看簡單選取start_logits的最大值和end_logits的最大值所對應的prediction（outputs_numpy）
# 與經過post_processing_function處理過後的prediction差別

for qs_id in range(10):

  start_idx = outputs_numpy[0][qs_id].argmax()
  end_idx = outputs_numpy[1][qs_id].argmax()
  print(str(start_idx)+" "+str(end_idx))
  print(' '.join(tokenizer.convert_ids_to_tokens(eval_dataset['input_ids'][qs_id][start_idx:end_idx+1])))
  print(prediction.predictions[qs_id]['prediction_text'])
  print('\n')
# Out:
# 49 49
# France
# France
#
#
# 37 40
# 10th and 11th centuries
# 10th and 11th centuries
#
#
# 59 65
# Norman " comes from " Norse ##man
# Norman" comes from "Norseman
#
#
# 81 82
# Roll ##o
# Rollo
#
#
# 41 165
# 10th and 11th centuries gave their name to Normandy , a region in France . They were descended from Norse ( " Norman " comes from " Norse ##man " ) raid ##ers and pirates from Denmark , Iceland and Norway who , under their leader Roll ##o , agreed to swear f ##eal ##ty to King Charles III of West Fr ##an ##cia . Through generations of ass ##im ##ilation and mixing with the native Frank ##ish and Roman - G ##aul ##ish populations , their descendants would gradually merge with the Carol ##ing ##ian - based cultures of West Fr ##an ##cia . The distinct cultural and ethnic identity of the Norman ##s emerged initially in the first half of the 10th century
# 10th century
#
#
# 57 47
#
# France
#
#
# 44 44
# Normandy
# Normandy
#
#
# 86 87
# Roll ##o
# Rollo
#
#
# 160 161
# 10th century
# 10th century
#
#
# 205 209
# William the Con ##quer ##or
# William the Conqueror

# %%
# 人工查看，比較預測結果與和答案

for i in range(10):
  print("====Question====")
  pp.pprint(datasets['validation'][i])
  print("\n====prediction====")
  pp.pprint(prediction.predictions[i])
  print("\n")
# Out:
# ====Question====
# {   'answers': {   'answer_start': [159, 159, 159, 159],
#                    'text': ['France', 'France', 'France', 'France']},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '56ddde6b9a695914005b9628',
#     'question': 'In what country is Normandy located?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '56ddde6b9a695914005b9628',
#     'no_answer_probability': 0.0,
#     'prediction_text': 'France'}
#
#
# ====Question====
# {   'answers': {   'answer_start': [94, 87, 94, 94],
#                    'text': [   '10th and 11th centuries',
#                                'in the 10th and 11th centuries',
#                                '10th and 11th centuries',
#                                '10th and 11th centuries']},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '56ddde6b9a695914005b9629',
#     'question': 'When were the Normans in Normandy?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '56ddde6b9a695914005b9629',
#     'no_answer_probability': 0.0,
#     'prediction_text': '10th and 11th centuries'}
#
#
# ====Question====
# {   'answers': {   'answer_start': [256, 256, 256, 256],
#                    'text': [   'Denmark, Iceland and Norway',
#                                'Denmark, Iceland and Norway',
#                                'Denmark, Iceland and Norway',
#                                'Denmark, Iceland and Norway']},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '56ddde6b9a695914005b962a',
#     'question': 'From which countries did the Norse originate?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '56ddde6b9a695914005b962a',
#     'no_answer_probability': 0.0,
#     'prediction_text': 'Norman" comes from "Norseman'}
#
#
# ====Question====
# {   'answers': {   'answer_start': [308, 308, 308, 308],
#                    'text': ['Rollo', 'Rollo', 'Rollo', 'Rollo']},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '56ddde6b9a695914005b962b',
#     'question': 'Who was the Norse leader?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '56ddde6b9a695914005b962b',
#     'no_answer_probability': 0.0,
#     'prediction_text': 'Rollo'}
#
#
# ====Question====
# {   'answers': {   'answer_start': [671, 649, 671, 671],
#                    'text': [   '10th century',
#                                'the first half of the 10th century',
#                                '10th',
#                                '10th']},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '56ddde6b9a695914005b962c',
#     'question': 'What century did the Normans first gain their separate '
#                 'identity?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '56ddde6b9a695914005b962c',
#     'no_answer_probability': 0.0,
#     'prediction_text': '10th century'}
#
#
# ====Question====
# {   'answers': {'answer_start': [], 'text': []},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '5ad39d53604f3c001a3fe8d1',
#     'question': "Who gave their name to Normandy in the 1000's and 1100's",
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '5ad39d53604f3c001a3fe8d1',
#     'no_answer_probability': 0.0,
#     'prediction_text': 'France'}
#
#
# ====Question====
# {   'answers': {'answer_start': [], 'text': []},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '5ad39d53604f3c001a3fe8d2',
#     'question': 'What is France a region of?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '5ad39d53604f3c001a3fe8d2',
#     'no_answer_probability': 0.0,
#     'prediction_text': 'Normandy'}
#
#
# ====Question====
# {   'answers': {'answer_start': [], 'text': []},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '5ad39d53604f3c001a3fe8d3',
#     'question': 'Who did King Charles III swear fealty to?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '5ad39d53604f3c001a3fe8d3',
#     'no_answer_probability': 0.0,
#     'prediction_text': 'Rollo'}
#
#
# ====Question====
# {   'answers': {'answer_start': [], 'text': []},
#     'context': 'The Normans (Norman: Nourmands; French: Normands; Latin: '
#                'Normanni) were the people who in the 10th and 11th centuries '
#                'gave their name to Normandy, a region in France. They were '
#                'descended from Norse ("Norman" comes from "Norseman") raiders '
#                'and pirates from Denmark, Iceland and Norway who, under their '
#                'leader Rollo, agreed to swear fealty to King Charles III of '
#                'West Francia. Through generations of assimilation and mixing '
#                'with the native Frankish and Roman-Gaulish populations, their '
#                'descendants would gradually merge with the Carolingian-based '
#                'cultures of West Francia. The distinct cultural and ethnic '
#                'identity of the Normans emerged initially in the first half of '
#                'the 10th century, and it continued to evolve over the '
#                'succeeding centuries.',
#     'id': '5ad39d53604f3c001a3fe8d4',
#     'question': 'When did the Frankish identity emerge?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '5ad39d53604f3c001a3fe8d4',
#     'no_answer_probability': 0.0,
#     'prediction_text': '10th century'}
#
#
# ====Question====
# {   'answers': {   'answer_start': [1022, 1022, 1022],
#                    'text': [   'William the Conqueror',
#                                'William the Conqueror',
#                                'William the Conqueror']},
#     'context': 'The Norman dynasty had a major political, cultural and '
#                'military impact on medieval Europe and even the Near East. The '
#                'Normans were famed for their martial spirit and eventually for '
#                'their Christian piety, becoming exponents of the Catholic '
#                'orthodoxy into which they assimilated. They adopted the '
#                'Gallo-Romance language of the Frankish land they settled, '
#                'their dialect becoming known as Norman, Normaund or Norman '
#                'French, an important literary language. The Duchy of Normandy, '
#                'which they formed by treaty with the French crown, was a great '
#                'fief of medieval France, and under Richard I of Normandy was '
#                'forged into a cohesive and formidable principality in feudal '
#                'tenure. The Normans are noted both for their culture, such as '
#                'their unique Romanesque architecture and musical traditions, '
#                'and for their significant military accomplishments and '
#                'innovations. Norman adventurers founded the Kingdom of Sicily '
#                'under Roger II after conquering southern Italy on the Saracens '
#                'and Byzantines, and an expedition on behalf of their duke, '
#                'William the Conqueror, led to the Norman conquest of England '
#                'at the Battle of Hastings in 1066. Norman cultural and '
#                'military influence spread from these new European centres to '
#                'the Crusader states of the Near East, where their prince '
#                'Bohemond I founded the Principality of Antioch in the Levant, '
#                'to Scotland and Wales in Great Britain, to Ireland, and to the '
#                'coasts of north Africa and the Canary Islands.',
#     'id': '56dddf4066d3e219004dad5f',
#     'question': 'Who was the duke in the battle of Hastings?',
#     'title': 'Normans'}
#
# ====prediction====
# {   'id': '56dddf4066d3e219004dad5f',
#     'no_answer_probability': 0.0,
#     'prediction_text': 'William the Conqueror'}

# %%
# 儲存微調好的模型

if args.output_dir is not None:
    accelerator.wait_for_everyone()
    unwrapped_model = accelerator.unwrap_model(model)
    unwrapped_model.save_pretrained(args.output_dir, save_function=accelerator.save)
